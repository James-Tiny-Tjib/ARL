# %%
print("kevin"*67)
# Out:
# ARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARLARL
